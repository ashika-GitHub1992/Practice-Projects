# %% [markdown]
# # RED WINE QUALITY PREDICTION

# %%
#import libraries
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization

# %% [markdown]
# Scatter Plot:

# %%
import seaborn as sns
sns.scatterplot(x='fixed acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %% [markdown]
# We can see that fixed acidity is equally distributed in the range 4 to 13.

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %% [markdown]
# We can see that volatile acidity is equally distributed in the range 0.18 to 0.85.

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %% [markdown]
# We can see that citric acid is equally distributed in the range 0 to 0.6.

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %% [markdown]
# We can see that residual sugar is equally distributed in the range 1 to 5.

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %% [markdown]
# We can see that chlorides is equally distributed in the range 0.05 to 0.13.

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %% [markdown]
# We can see that free sulfur dioxide is equally distributed in the range 3 to 28.

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %% [markdown]
# We can see that total sulfur dioxide is equally distributed in the range 10 to 75.

# %%
sns.scatterplot(x='density',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %% [markdown]
# We can see that density is equally distributed in the range 0.993 to 0.999.

# %%
sns.scatterplot(x='pH',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %% [markdown]
# We can see that pH is equally distributed in the range 3.15 to 3.45.

# %%
sns.scatterplot(x='sulphates',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %% [markdown]
# We can see that fixed sulphates is equally distributed in the range 0.49 to 079.

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %% [markdown]
# We can see that alcohol is equally distributed in the range 9.5 to 12.2.

# %% [markdown]
# Normal Distribution Curve:

# %%
sns.distplot(df["fixed acidity"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df["citric acid"])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df["residual sugar"])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df["chlorides"])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df["free sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["total sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["density"])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df["pH"])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df["sulphates"])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df["alcohol"])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# From the above observations we can see that, all the columns of the dataset are not normalized.The building blocks are outside the normalized curve.

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# correlation using heatmap:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidth=1.0, linecolor='black', fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome of correlation:

# %% [markdown]
# The columns of the dataset are positively and negatively correlated with the target column.
# fixed acidity is 12% correlated with the target column which is not a good bond.
# volatile acidity is 39% correlated with the target column which is a good bond.
# citric acid is 23% correlated with the target column which is a good bond.
# residual sugar is 1% correlated which is considered to be the weak bond.
# chlorides is 13% correlated with the target column which is a good bond.
# free sulfur dioxide is 5% correlated which is a weak bond.
# total sulfur dioxide is 19% correlated which is a good bond.
# density is 17% correlated which is a good bond.
# pH is 6% correlated which is a poor bond.
# sulphates is 25% correlated which is a good bond.
# alcohol is 48% correlated with the target column which is the strong bond.

# %% [markdown]
# Maximum correlation: alcohol
#
# Minumum correlation: residual sugar

# %% [markdown]
# # Describing datasets:

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Describing dataset using heatmap:

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome of describe of datasets:

# %% [raw]
# From the above plotting we can determine mean,standard deviation,minimum and maximum value of each column.
#
# 1.1599 rows
# 2.12 columns
#
# fixed acidity:
#     1.mean=8.320000
#     2.std=1.740000
#     3.max_value=15.900000
#     4.min_value=4.600000
#
# volatile acidity:
#     1.mean=0.530000
#     2.std=0.180000
#     3.max_value=15.80000
#     4.min_value=0.120000
#
# citric acid:
#     1.mean=0.270000
#     2.std=0.190000
#     3.max_value=1.000000
#     4.min_value0.000000
#
# residual sugar:
#     1.mean=2.540000
#     2.std=1.410000
#     3.max_value=15.500000
#     4.min_value=0.900000
#
# chlorides:
#     1.mean=0.090000
#     2.std=0.050000
#     3.max_value=0.610000
#     4.min_value=0.010000
#
# free sulfur dioxide:
#     1.mean=15.870000
#     2.std=10.460000
#     3.max_value=72.000000
#     4.min_value=1.000000
#
# total sulfur dioxide:
#     1.mean=46.470000
#     2.std=32.9000000
#     3.max_value=289.000000
#     4.min_value=6.000000
#
# density:
#     1.mean=1.000000
#     2.std=0.000000
#     3.max_value=1.000000
#     4.min_value=0.990000
#
# pH:
#     1.mean=3.310000
#     2.std=0.150000
#     3.max_value=4.010000
#     4.min_value=2.740000
#
# sulphates:
#     1.mean=0.660000
#     2.std=0.170000
#     3.max_value=2.000000
#     4.min_value=0.330000
#
# alcohol:
#     1.mean=10.470000
#     2.std=1.070000
#     3.max_value=14.900000
#     4.min_value=8.4000000
#
# quality:
#     1.mean=5.640000
#     2.std=0.810000
#     3.max_value=8.000000
#     4.min_value=3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Outliers Checking:

# %%
df['fixed acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['volatile acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['citric acid'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['residual sugar'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['chlorides'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['free sulfur dioxide'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['total sulfur dioxide'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['density'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['pH'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['sulphates'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['alcohol'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['quality'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above observation, we can see that columns[fixed acidity,volatile acidity,residual sugar,chlorides,free sulfur dioxide,total sulphur dioxide,density,pH,sulphates]
# has more outliers and columns[citric acid,alcohol,quality] has less outliers.

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# Outcome of skewness:

# %% [raw]
# Skewness threshold taken is +/-0.5.
# Columns which are having skewness:
#     residual sugar
#     Chlorides
#     free sulfur dioxide
#     total sulfur dioxide
#     sulphates

# %% [markdown]
# # Data Cleaning:

# %%
df=df.drop(["residual sugar","pH"],axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0               7.4             0.700         0.00      0.076
# 1               7.8             0.880         0.00      0.098
# 2               7.8             0.760         0.04      0.092
# 3              11.2             0.280         0.56      0.075
# 4               7.4             0.700         0.00      0.076
# ...             ...               ...          ...        ...
# 1594            6.2             0.600         0.08      0.090
# 1595            5.9             0.550         0.10      0.062
# 1596            6.3             0.510         0.13      0.076
# 1597            5.9             0.645         0.12      0.075
# 1598            6.0             0.310         0.47      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# 0                    11.0                  34.0  0.99780       0.56      9.4
# ...

# %% [markdown]
# Here, we are setting the threshold of correlation as +/-0.1.

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# z-score technique:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   38,   42,   43,   57,
#          81,   81,   83,   86,   88,   91,   92,  106,  106,  109,  120,
#         126,  127,  142,  144,  147,  151,  151,  151,  169,  169,  181,
#         199,  226,  226,  240,  243,  244,  258,  258,  281,  291,  339,
#         340,  347,  354,  374,  381,  391,  396,  400,  442,  442,  451,
#         459,  467,  480,  515,  517,  544,  554,  554,  555,  555,  557,
#         557,  568,  584,  588,  591,  608,  614,  636,  639,  649,  651,
#         652,  652,  672,  672,  684,  690,  690,  692,  692,  723,  724,
#         730,  754,  776,  777,  795,  821,  832,  836,  837,  889,  899,
#         925,  926,  982, 1017, 1018, 1051, 1051, 1079, 1081, 1114, 1131,
#        1154, 1165, 1175, 1231, 1244, 1244, 1260, 1269, 1269, 1270, 1270,
#        1288, 1289, 1295, 1296, 1299, 1299, 1312, 1319, 1319, 1358, 1367,
#        1370, 1370, 1372, 1372, 1374, 1374, 1434, 1434, 1435, 1435, 1469,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (1599, 10)
# (1476, 10)

# %% [markdown]
# Percentage Data Loss:

# %%
percentage_loss=(1599-1476)/1599*100
print(percentage_loss)
# Out:
# 7.6923076923076925

# %% [markdown]
# IQR Technique:

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# fixed acidity            2.100000
# volatile acidity         0.250000
# citric acid              0.330000
# chlorides                0.020000
# free sulfur dioxide     14.000000
# total sulfur dioxide    40.000000
# density                  0.002235
# sulphates                0.180000
# alcohol                  1.600000
# quality                  1.000000
# dtype: float64

# %%
df_new1= df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_new1.shape)
# Out:
# (1295, 10)

# %% [markdown]
# Percentage Data Loss:

# %%
percentage_loss=((1599-1295)/1599)*100
print(percentage_loss)
# Out:
# 19.011882426516575

# %% [markdown]
# The percentage loss in the z-score is less, so we prefer z-score over IQR.

# %% [markdown]
# # Dividing dataframe into feature and target:

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %%
y.value_counts()
# Out:
# 5    625
# 6    599
# 7    187
# 4     49
# 8     16
# Name: quality, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
xtrain,ytrain=sm.fit_resample(x,y)

# %%
ytrain.value_counts()
# Out:
# 4    625
# 6    625
# 8    625
# 5    625
# 7    625
# Name: quality, dtype: int64

# %% [markdown]
# # Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
xtrain=power_transform(x,method='yeo-johnson')
xtrain
# Out:
# array([[-0.44980535,  1.05418705, -1.52703766, ...,  0.6290875 ,
#         -0.58554096, -1.11572062],
#        [-0.16130039,  1.92130548, -1.52703766, ...,  0.05609404,
#          0.45999391, -0.52986345],
#        [-0.16130039,  1.35645614, -1.24580743, ...,  0.17105656,
#          0.2278293 , -0.52986345],
#        ...,
#        [-1.38976075, -0.00655102, -0.66318779, ..., -0.55626209,
#          0.93957581,  0.73447772],
#        [-1.79853182,  0.76420294, -0.72478467, ..., -0.71306445,
#          0.67554183, -0.03719329],
#        [-1.69236379, -1.33706636,  1.07597982, ..., -0.70143794,
#          0.30716003,  0.73447772]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtrain
# Out:
# array([[-0.44980535,  1.05418705, -1.52703766, ...,  0.6290875 ,
#         -0.58554096, -1.11572062],
#        [-0.16130039,  1.92130548, -1.52703766, ...,  0.05609404,
#          0.45999391, -0.52986345],
#        [-0.16130039,  1.35645614, -1.24580743, ...,  0.17105656,
#          0.2278293 , -0.52986345],
#        ...,
#        [-1.38976075, -0.00655102, -0.66318779, ..., -0.55626209,
#          0.93957581,  0.73447772],
#        [-1.79853182,  0.76420294, -0.72478467, ..., -0.71306445,
#          0.67554183, -0.03719329],
#        [-1.69236379, -1.33706636,  1.07597982, ..., -0.70143793,
#          0.30716003,  0.73447772]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# # Model Building

# %% [markdown]
# Logistic Regression:

# %%
for i in range(0,1000):
    train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20,random_state=i)
    lg.fit(train_x,train_y)
    pred_train=lg.predict(train_x)
    pred_test=lg.predict(test_x)
    if round(accuracy_score(train_y,pred_train)*100,1)==round(accuracy_score(test_y,pred_test)*100,1):
        print("At random state",i,"The model performs well")
        print("At random state:",i)
        print("Training Accuracy:",accuracy_score(train_y,pred_train)*100)
        print("Testing Accuracy:",accuracy_score(test_y,pred_test)*100)
# Out:
# At random state 55 The model performs well
# At random state: 55
# Training Accuracy: 56.779661016949156
# Testing Accuracy: 56.75675675675676
# At random state 93 The model performs well
# At random state: 93
# Training Accuracy: 57.11864406779661
# Testing Accuracy: 57.0945945945946
# At random state 105 The model performs well
# At random state: 105
# Training Accuracy: 56.779661016949156
# Testing Accuracy: 56.75675675675676
# At random state 192 The model performs well
# At random state: 192
# Training Accuracy: 56.440677966101696
# Testing Accuracy: 56.41891891891891
# At random state 205 The model performs well
# At random state: 205
# Training Accuracy: 57.11864406779661
# Testing Accuracy: 57.0945945945946
# At random state 230 The model performs well
# At random state: 230
# Training Accuracy: 57.11864406779661
# Testing Accuracy: 57.0945945945946
# At random state 353 The model performs well
# At random state: 353
# Training Accuracy: 56.779661016949156
# ...

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20,random_state=620)
print("Classification Report:",classification_report(test_y,pred_test))
print("Confusion Matrix:",confusion_matrix(test_y,pred_test))
# Out:
# Classification Report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.51      0.52      0.52       140
#            6       0.40      0.56      0.46       109
#            7       0.00      0.00      0.00        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.45       296
#    macro avg       0.18      0.22      0.20       296
# weighted avg       0.39      0.45      0.42       296
#
# Confusion Matrix: [[ 0  4  5  0  0]
#  [ 0 73 67  0  0]
#  [ 0 48 61  0  0]
#  [ 0 16 21  0  0]
#  [ 0  1  0  0  0]]

# %% [markdown]
# Cross validation score for Logistic Regression:

# %%
from sklearn.model_selection import cross_val_score

lg.fit(train_x,train_y)
lg.score(train_x,train_y)
pred_lg = lg.predict(test_x)

lss = accuracy_score(test_y,pred_lg)
for j in range(2,10):
    lsscore = cross_val_score(lg,x,y,cv=j)
    ls_cv = lsscore.mean() 
    print("At cv:-",j)
    print("Cross validation score is:-",ls_cv*100 )
    print("Accuracy score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 52.77777777777778
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 3
# Cross validation score is:- 55.35230352303523
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 4
# Cross validation score is:- 55.62330623306233
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 5
# Cross validation score is:- 56.71094823637197
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 6
# Cross validation score is:- 55.82655826558266
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 7
# Cross validation score is:- 56.16339426765966
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 8
# Cross validation score is:- 55.22289952996475
# Accuracy score is :- 58.108108108108105
#
#
# At cv:- 9
# Cross validation score is:- 56.504065040650396
# Accuracy score is :- 58.108108108108105

# %%
print("At cv:",5)
print("Cross validation score is:",56.71094 )
print("Accuracy score is :",58.10810)
# Out:
# At cv: 5
# Cross validation score is: 56.71094
# Accuracy score is : 58.1081

# %% [markdown]
# The value of cv taken is 5

# %% [markdown]
# # Approaching more classifiers:

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # 1.Decision Tree Classifier:

# %%
parameters = {'criterion':['gini', 'entropy'],'splitter':['best','random']}
dtc = DecisionTreeClassifier()
clf = GridSearchCV(dtc,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'splitter': 'random'}

# %%
dtc = DecisionTreeClassifier(criterion='entropy', splitter='best')
dtc.fit(train_x,train_y)
dtc.score(train_x,train_y)
pred_dtc = dtc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_dtc)*100)
print("Classification report:",classification_report(test_y,pred_dtc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_dtc)*100)

dtc_score = cross_val_score(dtc,x,y,cv=5)
dtc_cc = dtc_score.mean() 
print('Cross Val Score:',dtc_cc*100)
# Out:
# Accuracy Score: 63.17567567567568
# Classification report:               precision    recall  f1-score   support
#
#            4       0.11      0.11      0.11         9
#            5       0.74      0.69      0.71       140
#            6       0.58      0.60      0.59       109
#            7       0.61      0.68      0.64        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.63       296
#    macro avg       0.41      0.41      0.41       296
# weighted avg       0.64      0.63      0.64       296
#               precision    recall  f1-score   support
#
#            4       0.11      0.11      0.11         9
#            5       0.74      0.69      0.71       140
#            6       0.58      0.60      0.59       109
#            7       0.61      0.68      0.64        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.63       296
# ...

# %% [markdown]
# # 2.KNeighbors Classifier:

# %%
parameters = {'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute']}
knc = KNeighborsClassifier()
clf = GridSearchCV(knc,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'algorithm': 'auto'}

# %%
knc = KNeighborsClassifier(algorithm='auto', n_neighbors=5)
knc.fit(train_x,train_y)
knc.score(train_x,train_y)
pred_knc = knc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_knc)*100)
print("Classification report:",classification_report(test_y,pred_knc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_knc)*100)

knc_score = cross_val_score(knc,x,y,cv=5)
knc_cc = knc_score.mean() 
print('Cross Val Score:',knc_cc*100)
# Out:
# Accuracy Score: 54.391891891891895
# Classification report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.62      0.61      0.62       140
#            6       0.47      0.55      0.50       109
#            7       0.68      0.41      0.51        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.54       296
#    macro avg       0.35      0.31      0.33       296
# weighted avg       0.55      0.54      0.54       296
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.62      0.61      0.62       140
#            6       0.47      0.55      0.50       109
#            7       0.68      0.41      0.51        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.54       296
# ...

# %% [markdown]
# # 3.MultinomialNB:

# %%
parameters = {'alpha':[1.0]}
mnb = MultinomialNB()
clf = GridSearchCV(mnb,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'alpha': 1.0}

# %%
mnb = MultinomialNB(alpha=1.0)
mnb.fit(train_x,train_y)
mnb.score(train_x,train_y)
pred_mnb = mnb.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_mnb)*100)
print("Classification report:",classification_report(test_y,pred_mnb)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_mnb)*100)

mnb_score = cross_val_score(mnb,x,y,cv=5)
mnb_cc = mnb_score.mean() 
print('Cross Val Score:',mnb_cc*100)
# Out:
# Accuracy Score: 42.9054054054054
# Classification report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.63      0.44      0.52       140
#            6       0.41      0.46      0.43       109
#            7       0.25      0.41      0.31        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.43       296
#    macro avg       0.26      0.26      0.25       296
# weighted avg       0.48      0.43      0.44       296
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.63      0.44      0.52       140
#            6       0.41      0.46      0.43       109
#            7       0.25      0.41      0.31        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.43       296
# ...

# %% [markdown]
# # 4.SVC:

# %%
svc = SVC(kernel='poly')
svc.fit(train_x,train_y)
svc.score(train_x,train_y)
pred_svc = svc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_svc)*100)
print("Classification report:",classification_report(test_y,pred_svc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_svc)*100)

svc_score = cross_val_score(svc,x,y,cv=5)
svc_cc = svc_score.mean() 
print('Cross Val Score:',svc_cc*100)
# Out:
# Accuracy Score: 46.28378378378378
# Classification report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.77      0.26      0.39       140
#            6       0.40      0.92      0.56       109
#            7       0.00      0.00      0.00        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.46       296
#    macro avg       0.23      0.24      0.19       296
# weighted avg       0.51      0.46      0.39       296
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.77      0.26      0.39       140
#            6       0.40      0.92      0.56       109
#            7       0.00      0.00      0.00        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.46       296
# ...

# %% [markdown]
# # ENSEMBLE METHODS:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # 1.Random Forest Classifier:

# %%
parameters = {'criterion':['gini', 'entropy'],'n_estimators':[100]}
rfc = RandomForestClassifier()
clf = GridSearchCV(rfc,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'criterion': 'gini', 'n_estimators': 100}

# %%
rfc = RandomForestClassifier(criterion='entropy', n_estimators=100)
rfc.fit(train_x,train_y)
rfc.score(train_x,train_y)
pred_rfc = rfc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_rfc)*100)
print("Classification report:",classification_report(test_y,pred_rfc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_rfc)*100)

rfc_score = cross_val_score(rfc,x,y,cv=5)
rfc_cc = rfc_score.mean() 
print('Cross Val Score:',rfc_cc*100)
# Out:
# Accuracy Score: 70.6081081081081
# Classification report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.77      0.78      0.78       140
#            6       0.63      0.70      0.66       109
#            7       0.71      0.65      0.68        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.71       296
#    macro avg       0.42      0.42      0.42       296
# weighted avg       0.69      0.71      0.69       296
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.77      0.78      0.78       140
#            6       0.63      0.70      0.66       109
#            7       0.71      0.65      0.68        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.71       296
# ...

# %% [markdown]
# # 2.Ada Boost Classifier:

# %%
abc = AdaBoostClassifier(n_estimators=50, learning_rate=1.0, algorithm='SAMME')
abc.fit(train_x,train_y)
abc.score(train_x,train_y)
pred_abc = abc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_abc)*100)
print("Classification report:",classification_report(test_y,pred_abc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_abc)*100)

abc_score = cross_val_score(abc,x,y,cv=5)
abc_cc = abc_score.mean() 
print('Cross Val Score:',abc_cc*100)
# Out:
# Accuracy Score: 56.08108108108109
# Classification report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.67      0.80      0.73       140
#            6       0.46      0.42      0.44       109
#            7       0.32      0.22      0.26        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.56       296
#    macro avg       0.29      0.29      0.28       296
# weighted avg       0.52      0.56      0.54       296
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.67      0.80      0.73       140
#            6       0.46      0.42      0.44       109
#            7       0.32      0.22      0.26        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.56       296
# ...

# %% [markdown]
# # 3.Gradient Boosting Classifier:

# %%
parameters = {'criterion':['friedman_mse', 'mse', 'mae'],'n_estimators':[100], 'loss':['deviance', 'exponential'], 'learning_rate':[0.1]}
gbc = GradientBoostingClassifier()
clf = GridSearchCV(gbc,parameters)
clf.fit(train_x,train_y)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'learning_rate': 0.1, 'loss': 'deviance', 'n_estimators': 100}

# %%
gbc = GradientBoostingClassifier(criterion='mse', n_estimators=100, learning_rate=0.1, loss='deviance')
gbc.fit(train_x,train_y)
gbc.score(train_x,train_y)
pred_gbc = gbc.predict(test_x)

print("Accuracy Score:",accuracy_score(test_y,pred_gbc)*100)
print("Classification report:",classification_report(test_y,pred_gbc)*100)
print("Confusion Matrix:",confusion_matrix(test_y,pred_gbc)*100)

gbc_score = cross_val_score(gbc,x,y,cv=5)
gbc_cc = gbc_score.mean() 
print('Cross Val Score:',gbc_cc*100)
# Out:
# Accuracy Score: 64.52702702702703
# Classification report:               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.74      0.68      0.71       140
#            6       0.56      0.66      0.61       109
#            7       0.73      0.65      0.69        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.65       296
#    macro avg       0.41      0.40      0.40       296
# weighted avg       0.65      0.65      0.64       296
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         9
#            5       0.74      0.68      0.71       140
#            6       0.56      0.66      0.61       109
#            7       0.73      0.65      0.69        37
#            8       0.00      0.00      0.00         1
#
#     accuracy                           0.65       296
# ...

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename='red_wine_quality.pkl'
pickle.dump(abc,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(test_y)
predicted=np.array(abc.predict(test_x))
df_com=pd.DataFrame({"original":a,"predicted":predicted},index=range(len(a)))
df_com
# Out:
#      original  predicted
# 0           5          5
# 1           7          5
# 2           5          5
# 3           5          6
# 4           7          6
# ..        ...        ...
# 291         6          6
# 292         6          6
# 293         5          5
# 294         6          5
# 295         5          5
#
# [296 rows x 2 columns]

# %% [markdown]
# From the above table, the model is predicted with 53 to 56 percent accuracy.
